# %% [markdown]
# # 9.4. Recurrent Neural Networks

# %% [markdown]
# ## 📘 Code Along

# %%
import torch

# %% [markdown]
# ### 9.4.1. Neural Networks without Hidden States

# %% [markdown]
# ### 9.4.2. Recurrent Neural Networks with Hidden States

# %%
X, W_xh = torch.randn(3, 1), torch.randn(1, 4)
H, W_hh = torch.randn(3, 4), torch.randn(4, 4)
torch.matmul(X, W_xh) + torch.matmul(H, W_hh)
# Out:
# tensor([[ 5.2167,  6.4508,  1.8430,  3.4338],
#         [ 1.5093,  1.8895, -1.4027,  1.1672],
#         [-3.8431, -6.6537, -0.0504, -2.2159]])

# %%
torch.matmul(torch.cat((X, H), 1), torch.cat((W_xh, W_hh), 0))
# Out:
# tensor([[ 5.2167,  6.4508,  1.8430,  3.4338],
#         [ 1.5093,  1.8895, -1.4027,  1.1672],
#         [-3.8431, -6.6537, -0.0504, -2.2159]])

# %% [markdown]
# ### 9.4.3. RNN-Based Character-Level Language Models
