# %% [markdown]
# # 9.3. Language Models

# %% [markdown]
# ## 📘 Code Along

# %%
import torch

import sys
sys.path.append("../..")
from dataloaders import TimeMachine

# %%
data = TimeMachine(batch_size=2, num_steps=10)
for X, Y in data.train_dataloader():
    print('X:', X, '\nY:', Y)
    break
# Out:
# X: tensor([[ 2,  3, 13,  6,  0, 21,  9, 10, 15,  8],
#         [15,  6, 23,  6, 19,  0,  4, 16, 15, 23]])
# Y: tensor([[ 3, 13,  6,  0, 21,  9, 10, 15,  8,  0],
#         [ 6, 23,  6, 19,  0,  4, 16, 15, 23, 10]])
